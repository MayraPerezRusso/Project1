# %%
import pandas as pd
data=pd.read_csv("Data.csv")
data.head()
# Out:
#               City     State  Zipcode Gender  Less than 5 minutes  \
# 0  Birmingham city   Alabama     7000   Male                619.0
# 1      Dothan city   Alabama    21184   Male                218.0
# 2      Hoover city   Alabama    35896   Male                  0.0
# 3  Huntsville city   Alabama    37000   Male               1123.0
# 4      Mobile city   Alabama    50000   Male                259.0
#
#    5 to 9 minutes  10 to 14 minutes  15 to 19 minutes  20 to 24 minutes  \
# 0          5594.0            6434.0           10770.0            8463.0
# 1          1546.0            2805.0            3857.0            1960.0
# 2          2195.0            1883.0            3611.0            3279.0
# 3          4870.0            6805.0           10147.0            8854.0
# 4          4038.0            6686.0            7708.0            6690.0
#
#    25 to 29 minutes  ...   30000 to 34999 USD  35000 to 39999 USD  \
# ...

# %%
data["City"]=data['City'].str.replace(' city.*' , '')
data["State"]=data['State'].str.strip()
data.head()
# Out:
#          City    State  Zipcode Gender  Less than 5 minutes  5 to 9 minutes  \
# 0  Birmingham  Alabama     7000   Male                619.0          5594.0
# 1      Dothan  Alabama    21184   Male                218.0          1546.0
# 2      Hoover  Alabama    35896   Male                  0.0          2195.0
# 3  Huntsville  Alabama    37000   Male               1123.0          4870.0
# 4      Mobile  Alabama    50000   Male                259.0          4038.0
#
#    10 to 14 minutes  15 to 19 minutes  20 to 24 minutes  25 to 29 minutes  \
# 0            6434.0           10770.0            8463.0            2821.0
# 1            2805.0            3857.0            1960.0             304.0
# 2            1883.0            3611.0            3279.0            2422.0
# 3            6805.0           10147.0            8854.0            3488.0
# 4            6686.0            7708.0            6690.0            2111.0
#
# ...

# %%
#data['key1']=data["City"]+data["State"]+data["Year"].map(str)
datawogender=data.groupby(['City','State','Year']).sum()
#datawogender[datawogender['Year']=='2013']
datawogender.to_csv("test.csv",encoding="utf-8", index=False)
datawogender.head()
# Out:
#                     Zipcode  Less than 5 minutes  5 to 9 minutes  \
# City    State Year
# Abilene Texas 2013     2000               2725.0         11208.0
#               2014     2000               2487.0         12551.0
#               2015     2000               3090.0         12364.0
#               2016     2000               2530.0          8369.0
#               2017     2000               3080.0          7578.0
#
#                     10 to 14 minutes  15 to 19 minutes  20 to 24 minutes  \
# City    State Year
# Abilene Texas 2013           16135.0           13800.0            4716.0
#               2014           13137.0           12242.0            5264.0
#               2015           16247.0           14660.0            5263.0
#               2016           14764.0           15014.0            4373.0
#               2017           15988.0           15592.0            6055.0
#
#                     25 to 29 minutes  30 to 34 minutes  35 to 39 minutes  \
# ...

# %%
data"Less than 5 minutes",
"5 to 9 minutes",
"10 to 14 minutes",
"15 to 19 minutes",
"20 to 24 minutes",
"25 to 29 minutes",
"30 to 34 minutes",
"35 to 39 minutes",
"40 to 44 minutes",
"45 to 59 minutes",
"60 to 89 minutes",
"90 or more minutes"
